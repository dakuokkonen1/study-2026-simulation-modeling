# %% [markdown]
# # Агентная SIR: базовый опыт
#
# Три города по 1000 человек, исходный заражённый в третьем городе, seed 42, 100 дней.
#
# ## Рабочее окружение

# %%
using DrWatson
@quickactivate "project"
include(srcdir("experiments.jl"))
# Out:
# [ Info: Precompiling Agents [46ada45e-f475-11e8-01d0-f70cc89e6671]
# [ Info: Precompiling BlackBoxOptim [a134a8b2-14d6-55f6-9291-3336d3ab0209] (cache misses: wrong dep version loaded (2))
# [ Info: Precompiling Plots [91a5bcdd-55d7-5caf-9e0b-520d859cae80] (cache misses: wrong dep version loaded (2))
# [ Info: Precompiling RotationsRecipesBaseExt [d42e7fc9-5505-5e4e-af88-1fc2e1109285] (cache misses: wrong dep version loaded (2))
# [ Info: Precompiling StructUtilsTablesExt [06a1ca1f-7bc7-53d2-8cfe-f45bf2a4bdd3]
# [ Info: Precompiling StructUtilsStaticArraysCoreExt [5f8627f4-f0c5-5aac-996c-f7a3cc29134a]
# [ Info: Precompiling FileIOExt [f5f51d8f-5827-5d2e-939b-192fcd6ec70c] (cache misses: wrong dep version loaded (6))
# [ Info: Precompiling IJuliaExt [2f4121a4-3b3a-5ce6-9c5e-1f2673ce168a] (cache misses: wrong dep version loaded (2))
# comprehensive_analysis (generic function with 2 methods)

# %% [markdown]
# ## Выполнение и сохранение JLD2 / CSV

# %%
result = basic_experiment()
# Out:
# (df = 101×6 DataFrame
#  Row │ time   susceptible  infected  recovered  total  deaths
#      │ Int64  Int64        Int64     Int64      Int64  Int64
# ─────┼────────────────────────────────────────────────────────
#    1 │     0         2999         1          0   3000       0
#    2 │     1         2998         2          0   3000       0
#    3 │     2         2994         6          0   3000       0
#    4 │     3         2991         9          0   3000       0
#    5 │     4         2985        15          0   3000       0
#    6 │     5         2969        31          0   3000       0
#    7 │     6         2952        48          0   3000       0
#    8 │     7         2929        71          0   3000       0
#    9 │     8         2870       130          0   3000       0
#   10 │     9         2779       221          0   3000       0
#   11 │    10         2647       353          0   3000       0
#   ⋮  │   ⋮         ⋮          ⋮          ⋮        ⋮      ⋮
#   92 │    91            0      2543        149   2692     308
#   93 │    92            0      2459        215   2674     326
#   94 │    93            0      2670          0   2670     330
#   95 │    94            0      2669          1   2670     330
#   96 │    95            0      2668          1   2669     331
#   97 │    96            0      2666          3   2669     331
#   98 │    97            0      2669          0   2669     331
#   99 │    98            0      2662          7   2669     331
#  100 │    99            0      2651         17   2668     332
#  101 │   100            0      2640         25   2665     335
#                                                80 rows omitted, cities = 303×6 DataFrame
#  Row │ time   city   susceptible  infected  recovered  total
#      │ Int64  Int64  Int64        Int64     Int64      Int64
# ─────┼───────────────────────────────────────────────────────
#    1 │     0      1         1000         0          0   1000
#    2 │     0      2         1000         0          0   1000
#    3 │     0      3          999         1          0   1000
#    4 │     1      1          982         0          0    982
#    5 │     1      2         1009         0          0   1009
#    6 │     1      3         1007         2          0   1009
#    7 │     2      1          999         2          0   1001
#    8 │     2      2          957         3          0    960
#    9 │     2      3         1038         1          0   1039
#   10 │     3      1          984         4          0    988
#   11 │     3      2          968         1          0    969
#   ⋮  │   ⋮      ⋮         ⋮          ⋮          ⋮        ⋮
#  294 │    97      3            0       934          0    934
#  295 │    98      1            0       893          0    893
#  296 │    98      2            0       894          4    898
#  297 │    98      3            0       875          3    878
#  298 │    99      1            0       937          3    940
#  299 │    99      2            0       895          7    902
#  300 │    99      3            0       819          7    826
#  301 │   100      1            0       908          5    913
#  302 │   100      2            0       903          8    911
#  303 │   100      3            0       829         12    841
#                                              282 rows omitted, fig = Plot{Plots.GRBackend() n=4})

# %% [markdown]
# ## S, I, R и число живых

# %%
savefig(result.fig, imagefile("01-plot.png"))
display(result.fig)
result.df[1:10:end, :]
# Out:
# Plot{Plots.GRBackend() n=4}
# 11×6 DataFrame
#  Row │ time   susceptible  infected  recovered  total  deaths
#      │ Int64  Int64        Int64     Int64      Int64  Int64
# ─────┼────────────────────────────────────────────────────────
#    1 │     0         2999         1          0   3000       0
#    2 │    10         2647       353          0   3000       0
#    3 │    20            0      2989          8   2997       3
#    4 │    30            0      2951          1   2952      48
#    5 │    40            0      2681        229   2910      90
#    6 │    50            0      2835         51   2886     114
#    7 │    60            0      2818         14   2832     168
#    8 │    70            0      2781          2   2783     217
#    9 │    80            0      2724          0   2724     276
#   10 │    90            0      2598        102   2700     300
#   11 │   100            0      2640         25   2665     335
