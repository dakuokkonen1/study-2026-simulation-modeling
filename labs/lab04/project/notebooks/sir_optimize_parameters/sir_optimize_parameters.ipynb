# %% [markdown]
# # Агентная SIR: многокритериальная оптимизация
#
# Borg MOEA минимизирует средний пик и смертность; каждая оценка содержит пять прогонов.
#
# ## Рабочее окружение

# %%
using DrWatson
@quickactivate "project"
include(srcdir("experiments.jl"))
# Out:
# comprehensive_analysis (generic function with 2 methods)

# %% [markdown]
# ## Поиск с бюджетом методички 120 секунд

# %%
result = optimize_sir()
# Out:
# (df = 53×5 DataFrame
#  Row │ beta      detection_time  death_rate  peak        death_fraction
#      │ Float64   Int64           Float64     Float64     Float64
# ─────┼──────────────────────────────────────────────────────────────────
#    1 │ 0.5                    7   0.02       0.800067       0.0853333
#    2 │ 0.305381               8   0.0103763  0.599997       0.0307333
#    3 │ 0.530632               6   0.0129657  0.800067       0.0603333
#    4 │ 0.331604              12   0.0876372  1.0            0.3734
#    5 │ 0.757493              13   0.0344303  1.0            0.1912
#    6 │ 0.992581               3   0.0848965  1.0            0.432
#    7 │ 0.871729               7   0.0423062  1.0            0.2538
#    8 │ 0.473076              14   0.0667385  1.0            0.332733
#   ⋮  │    ⋮            ⋮             ⋮           ⋮             ⋮
#   47 │ 0.28464                9   0.051672   0.599999       0.137333
#   48 │ 0.903185               5   0.0782152  1.0            0.4162
#   49 │ 0.448226              11   0.0835847  1.0            0.390667
#   50 │ 0.565888              10   0.022658   0.800067       0.102533
#   51 │ 0.942215               4   0.0920743  1.0            0.471133
#   52 │ 0.177266               6   0.0369792  0.00863117     0.000866667
#   53 │ 0.104035               4   0.0838149  0.0004         0.0
#                                                          38 rows omitted, pareto = 1×5 DataFrame
#  Row │ beta      detection_time  death_rate  peak     death_fraction
#      │ Float64   Int64           Float64     Float64  Float64
# ─────┼───────────────────────────────────────────────────────────────
#    1 │ 0.104035               4   0.0838149   0.0004             0.0, best = [0.10403456055242873, 4.222320907857107, 0.08381493867268837], fitness = (0.0004, 0.0), fig = Plot{Plots.GRBackend() n=2})

# %% [markdown]
# ## Исследованные точки и недоминируемые решения

# %%
savefig(result.fig, imagefile("04-plot.png"))
display(result.fig)
result.pareto
# Out:
# Plot{Plots.GRBackend() n=2}
# 1×5 DataFrame
#  Row │ beta      detection_time  death_rate  peak     death_fraction
#      │ Float64   Int64           Float64     Float64  Float64
# ─────┼───────────────────────────────────────────────────────────────
#    1 │ 0.104035               4   0.0838149   0.0004             0.0
