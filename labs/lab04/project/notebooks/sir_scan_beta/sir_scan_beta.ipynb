# %% [markdown]
# # Агентная SIR: сканирование β
#
# Десять значений β и три seed, всего 30 независимых прогонов по 100 дней.
#
# ## Рабочее окружение

# %%
using DrWatson
@quickactivate "project"
include(srcdir("experiments.jl"))
# Out:
# comprehensive_analysis (generic function with 2 methods)

# %% [markdown]
# ## Численные эксперименты

# %%
result = beta_scan()
# Out:
# (df = 30×9 DataFrame
#  Row │ beta     seed   infection_period  peak         peak_time  final_inf  fi ⋯
#      │ Float64  Int64  Int64             Float64      Int64      Float64    Fl ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │     0.1     42                14  0.000333333          0   0.0       0. ⋯
#    2 │     0.1     43                14  0.002               12   0.0       0.
#    3 │     0.1     44                14  0.000333333          0   0.0       0.
#    4 │     0.2     42                14  0.995285            76   0.959902  0.
#    5 │     0.2     43                14  0.001                5   0.0       0. ⋯
#    6 │     0.2     44                14  0.000333333          0   0.0       0.
#    7 │     0.3     42                14  1.0                 57   0.992515  0.
#    8 │     0.3     43                14  0.999644            78   0.939349  0.
#   ⋮  │    ⋮       ⋮           ⋮               ⋮           ⋮          ⋮         ⋱
#   24 │     0.8     44                14  1.0                 12   0.976262  0. ⋯
#   25 │     0.9     42                14  1.0                 10   0.952674  0.
#   26 │     0.9     43                14  1.0                 11   0.937761  0.
#   27 │     0.9     44                14  1.0                  9   1.0       0.
#   28 │     1.0     42                14  1.0                  9   1.0       0. ⋯
#   29 │     1.0     43                14  1.0                  8   1.0       0.
#   30 │     1.0     44                14  1.0                  9   1.0       0.
#                                                    3 columns and 15 rows omitted, grouped = 10×6 DataFrame
#  Row │ beta     peak         final_inf  final_rec   deaths   death_fraction
#      │ Float64  Float64      Float64    Float64     Float64  Float64
# ─────┼──────────────────────────────────────────────────────────────────────
#    1 │     0.1  0.000888889   0.0       0.00111111    0.0         0.0
#    2 │     0.2  0.332206      0.319967  0.0138103    44.0         0.0146667
#    3 │     0.3  0.666659      0.643955  0.0228231   208.0         0.0693333
#    4 │     0.4  0.666889      0.629722  0.0371667   226.667       0.0755556
#    5 │     0.5  1.0           0.996625  0.0033747   317.667       0.105889
#    6 │     0.6  1.0           0.993352  0.00664828  348.0         0.116
#    7 │     0.7  1.0           0.962127  0.0378732   361.333       0.120444
#    8 │     0.8  1.0           0.946348  0.0536517   356.333       0.118778
#    9 │     0.9  1.0           0.963478  0.0365217   385.667       0.128556
#   10 │     1.0  1.0           1.0       0.0         407.333       0.135778, fig = Plot{Plots.GRBackend() n=3})

# %% [markdown]
# ## Средние показатели по повторам

# %%
savefig(result.fig, imagefile("02-plot.png"))
display(result.fig)
result.grouped
# Out:
# Plot{Plots.GRBackend() n=3}
# 10×6 DataFrame
#  Row │ beta     peak         final_inf  final_rec   deaths   death_fraction
#      │ Float64  Float64      Float64    Float64     Float64  Float64
# ─────┼──────────────────────────────────────────────────────────────────────
#    1 │     0.1  0.000888889   0.0       0.00111111    0.0         0.0
#    2 │     0.2  0.332206      0.319967  0.0138103    44.0         0.0146667
#    3 │     0.3  0.666659      0.643955  0.0228231   208.0         0.0693333
#    4 │     0.4  0.666889      0.629722  0.0371667   226.667       0.0755556
#    5 │     0.5  1.0           0.996625  0.0033747   317.667       0.105889
#    6 │     0.6  1.0           0.993352  0.00664828  348.0         0.116
#    7 │     0.7  1.0           0.962127  0.0378732   361.333       0.120444
#    8 │     0.8  1.0           0.946348  0.0536517   356.333       0.118778
#    9 │     0.9  1.0           0.963478  0.0365217   385.667       0.128556
#   10 │     1.0  1.0           1.0       0.0         407.333       0.135778
