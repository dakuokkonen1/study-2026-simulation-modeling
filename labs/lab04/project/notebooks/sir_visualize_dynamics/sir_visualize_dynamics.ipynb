# %% [markdown]
# # Агентная SIR: анализ сохранённых данных
#
# Только читаем результат sir_scan_beta.jl, повторного моделирования нет.
#
# ## Рабочее окружение

# %%
using DrWatson
@quickactivate "project"
include(srcdir("experiments.jl"))
# Out:
# comprehensive_analysis (generic function with 2 methods)

# %% [markdown]
# ## Чтение CSV и усреднение

# %%
result = comprehensive_analysis()
CSV.write(
    datafile("sir_visualize_dynamics", "summary.csv"),
    result.grouped,
)
# Out:
# "/workspace/labs/lab04/project/data/sir_visualize_dynamics/summary.csv"

# %% [markdown]
# ## Три панели сводного анализа

# %%
savefig(result.fig, imagefile("05-plot.png"))
display(result.fig)
result.grouped
# Out:
# Plot{Plots.GRBackend() n=4}
# 10×5 DataFrame
#  Row │ beta     peak         final_inf  deaths   final_rec
#      │ Float64  Float64      Float64    Float64  Float64
# ─────┼──────────────────────────────────────────────────────
#    1 │     0.1  0.000888889   0.0         0.0    0.00111111
#    2 │     0.2  0.332206      0.319967   44.0    0.0138103
#    3 │     0.3  0.666659      0.643955  208.0    0.0228231
#    4 │     0.4  0.666889      0.629722  226.667  0.0371667
#    5 │     0.5  1.0           0.996625  317.667  0.0033747
#    6 │     0.6  1.0           0.993352  348.0    0.00664828
#    7 │     0.7  1.0           0.962127  361.333  0.0378732
#    8 │     0.8  1.0           0.946348  356.333  0.0536517
#    9 │     0.9  1.0           0.963478  385.667  0.0365217
#   10 │     1.0  1.0           1.0       407.333  0.0
