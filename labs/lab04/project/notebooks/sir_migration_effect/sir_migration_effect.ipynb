# %% [markdown]
# # Агентная SIR: миграция
#
# Шесть интенсивностей, три seed, 150 дней; инфекция начинается в первом городе.
#
# ## Рабочее окружение

# %%
using DrWatson
@quickactivate "project"
include(srcdir("experiments.jl"))
# Out:
# comprehensive_analysis (generic function with 2 methods)

# %% [markdown]
# ## Серия из 18 прогонов

# %%
result = migration_scan()
# Out:
# (df = 18×8 DataFrame
#  Row │ intensity  seed   peak      peak_time  final_inf  final_rec    deaths   ⋯
#      │ Float64    Int64  Float64   Int64      Float64    Float64      Int64    ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │       0.0     42  0.333111         14   0.283369  0.0028551       198   ⋯
#    2 │       0.0     43  0.333333         14   0.289716  0.00106383      180
#    3 │       0.0     44  0.333333         17   0.294781  0.0             164
#    4 │       0.1     42  1.0              16   1.0       0.0             511
#    5 │       0.1     43  1.0              15   0.998394  0.00160578      509   ⋯
#    6 │       0.1     44  1.0              35   0.991994  0.00800641      502
#    7 │       0.2     42  1.0              16   0.999182  0.000817996     555
#    8 │       0.2     43  1.0              15   0.997954  0.00204583      556
#   ⋮  │     ⋮        ⋮       ⋮          ⋮          ⋮           ⋮         ⋮      ⋱
#   12 │       0.3     44  1.0              19   1.0       0.0             527   ⋯
#   13 │       0.4     42  1.0              18   0.99959   0.000409668     559
#   14 │       0.4     43  1.0              18   1.0       0.0             546
#   15 │       0.4     44  1.0              21   0.942799  0.0572008       535
#   16 │       0.5     42  1.0              20   1.0       0.0             528   ⋯
#   17 │       0.5     43  1.0              21   0.983951  0.0160494       570
#   18 │       0.5     44  1.0              19   1.0       0.0             547
#                                                      1 column and 3 rows omitted, grouped = 6×3 DataFrame
#  Row │ intensity  peak_time  peak
#      │ Float64    Float64    Float64
# ─────┼────────────────────────────────
#    1 │       0.0       15.0  0.333259
#    2 │       0.1       22.0  1.0
#    3 │       0.2       16.0  1.0
#    4 │       0.3       17.0  1.0
#    5 │       0.4       19.0  1.0
#    6 │       0.5       20.0  1.0, fig = Plot{Plots.GRBackend() n=2})

# %% [markdown]
# ## Время и доля инфицированных в пике

# %%
savefig(result.fig, imagefile("03-plot.png"))
display(result.fig)
result.grouped
# Out:
# Plot{Plots.GRBackend() n=2}
# 6×3 DataFrame
#  Row │ intensity  peak_time  peak
#      │ Float64    Float64    Float64
# ─────┼────────────────────────────────
#    1 │       0.0       15.0  0.333259
#    2 │       0.1       22.0  1.0
#    3 │       0.2       16.0  1.0
#    4 │       0.3       17.0  1.0
#    5 │       0.4       19.0  1.0
#    6 │       0.5       20.0  1.0
